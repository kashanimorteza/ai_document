# %% [markdown]
# # Description
#
# ```markdown
# Problem      :
# Resolve      : Learning : Deep Learning
# Field        :
# Algorithm    : Neural Network
# Network      : RNN
# Architecture : LSTM
# Action       :
# Loss         :
# Train        :
# Input        :
# Output       :
# Dataset      :
# ```

# %% [markdown]
# # General

# %% [markdown]
# Import

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
import keras as ks
import tensorflow as tf

# %% [markdown]
# # Example-1

# %%
x = tf.random.normal((32, 10, 8))
layer = ks.layers.LSTM(4)
output = layer(x)
print("Shape  : {}".format(output.shape))
print("output : {}".format(output))

# %% [markdown]
# # Example-2

# %%
x = tf.random.normal((32, 10, 8))
layer = ks.layers.LSTM(4, return_sequences=True, return_state=True)
whole_seq_output, final_memory_state, final_carry_state = layer(x)
print("whole_seq_output.  : {}".format(whole_seq_output.shape))
print("final_memory_state : {}".format(final_memory_state.shape))
print("final_carry_state  : {}".format(whole_seq_output.shape))
print("output             : {}".format(output))
