# %% [markdown]
# # AI > ML > Regression

# %% [markdown]
# ## Description
# ```
# Number         : 3
# Problem        : Regression
# Algorithm      : SGD (Gradient descent : Stochastic)
# Formula        : y=(wx1)+(wx2)+...+(wxn)+b
# Action-FN      : - - -
# Loss FN        : - - -
# Hyperparameter : - - -
# Type           : Multiple
# Input          : Feature and label
# Output         : Continuous value
# Dataset        : Structured : petrol_consumption
# ```

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Import dataset

# %%
dataset = pd.read_csv("petrol_consumption.csv")

# %% [markdown]
# ## Display dataset

# %%
rows, cols = dataset.shape
print(dataset.head(5))
print("rows: {}, cols:{}".format(rows, cols))
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410
# rows: 48, cols:5

# %% [markdown]
# ## Separate data and label

# %%
x = dataset.iloc[:, :4]
y = dataset.iloc[:, 4]

# %%
print(x.head(5))
print(y.head(5))
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
# 0    541
# 1    524
# 2    561
# 3    414
# 4    410
# Name: Petrol_Consumption, dtype: int64

# %% [markdown]
# ## Separate tarin and test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
print("x_train: {}".format(x_train.shape))
print("x_test: {}".format(x_test.shape))
print("y_train: {}".format(y_train.shape))
print("y_test: {}".format(y_test.shape))
# Out:
# x_train: (38, 4)
# x_test: (10, 4)
# y_train: (38,)
# y_test: (10,)

# %% [markdown]
# ## Normalization

# %%
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)

# %% [markdown]
# ## Train

# %%
mdl = SGDRegressor(max_iter=1000, random_state=42, eta0=0.01)
mdl.fit(x_train, y_train)
# Out:
# SGDRegressor(random_state=42)

# %%
print("w: {}".format(mdl.coef_))
print("b: {}".format(mdl.intercept_))
print("epochs:", mdl.n_iter_)
print("update:", mdl.t_)
# Out:
# w: [-40.26081779 -35.12674878 -17.45790655  75.75998778]
# b: [583.88044189]
# epochs: 152
# update: 5777.0

# %%
coeff_df = pd.DataFrame(mdl.coef_, x.columns)
print(coeff_df)
# Out:
#                                       0
# Petrol_tax                   -40.260818
# Average_income               -35.126749
# Paved_Highways               -17.457907
# Population_Driver_licence(%)  75.759988

# %% [markdown]
# ## Predict

# %%
y_pred = mdl.predict(x_test)
df = pd.DataFrame({"Actual": y_test, "Predicted": y_pred})
print(df)
# Out:
#     Actual   Predicted
# 29     534  469.307149
# 4      410  545.359692
# 26     577  589.573560
# 30     571  569.545859
# 32     577  649.760229
# 37     704  646.507804
# 34     487  511.371134
# 40     587  672.332550
# 7      467  501.852738
# 10     580  501.163301

# %% [markdown]
# ## Evaluation

# %%
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 56.772579068180654
# MSE: 4657.255837070635
# RMSE: 68.24409012559721
