# %% [markdown]
# # AI > ML > Classification

# %% [markdown]
# ## Description
# ```
# Number         : 3
# Problem        : Classification
# Algorithm      : Logistic
# Formula        : Weightes-Sum
# Action-FN      : Sigmoid
# Loss-FN        : Cross-Entropy-Binary
# Hyperparameter : - - -
# Train          : Supervised
# Input          : Feature and label
# Output         : Probability
# Dataset        : Structured : diabetes
# ```

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, zero_one_loss
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Import dataset

# %%
dataset = pd.read_csv("diabetes.csv")

# %% [markdown]
# ## Display dataset

# %%
print(dataset.head(5))
rows, cols = dataset.shape
print("rows: {}, cols:{}".format(rows, cols))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# rows: 768, cols:9

# %% [markdown]
# ## Missing values

# %%
zero_not_accepted = ['Glucose', 'BloodPressure','SkinThickness', 'BMI', 'Insulin']
for coloumn in zero_not_accepted:
  dataset[coloumn] = dataset[coloumn].replace(0, np.nan)
  mean = int(dataset[coloumn].mean(skipna=True))
  dataset[coloumn]=dataset[coloumn].replace(np.nan, mean)

# %% [markdown]
# ## Separate data and label

# %%
x = dataset.iloc[:, :8]
y = dataset.iloc[:, 8]
print(x.head(5))
print(y.head(5))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    155.0  33.6
# 1            1     85.0           66.0           29.0    155.0  26.6
# 2            8    183.0           64.0           29.0    155.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# ## Separate tarin and test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print("x_train: {}".format(x_train.shape))
print("x_test: {}".format(x_test.shape))
print("y_train: {}".format(y_train.shape))
print("y_test: {}".format(y_test.shape))
# Out:
# x_train: (614, 8)
# x_test: (154, 8)
# y_train: (614,)
# y_test: (154,)

# %% [markdown]
# ## Normalization

# %%
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)

# %% [markdown]
# ## Train

# %%
mdl = LogisticRegression()
mdl.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predict

# %%
y_pred = mdl.predict(x_test)
df_pred = pd.DataFrame({"Actual": y_test, "Predicted": y_pred})
df_pred["Correct"] = df_pred["Actual"] == df_pred["Predicted"]
print(df_pred)
# Out:
#      Actual  Predicted  Correct
# 668       0          0     True
# 324       0          0     True
# 624       0          0     True
# 690       0          0     True
# 473       0          0     True
# ..      ...        ...      ...
# 355       1          1     True
# 534       0          0     True
# 344       0          0     True
# 296       1          0    False
# 462       0          0     True
#
# [154 rows x 3 columns]

# %% [markdown]
# ## Accuracy and Loss

# %%
accuracy = accuracy_score(y_test, y_pred) * 100
loss = zero_one_loss(y_test, y_pred) * 100
accuracy2 = mdl.score(x_test, y_test) * 100
print("Accuracy: {:.2f} | Loss: {:.2f} | accuracy2: {:.2f}".format(accuracy, loss, accuracy2))
# Out:
# Accuracy: 75.32 | Loss: 24.68 | accuracy2: 75.32

# %% [markdown]
# ## Weight and Bias

# %%
weightes = mdl.coef_
bias = mdl.intercept_
epochs = mdl.n_iter_
print("epochs: {} | Bias: {} | Weightes: {}".format(epochs, bias, weightes))
# Out:
# epochs: [9] | Bias: [-0.87702892] | Weightes: [[ 0.22490422  1.08377074 -0.14709905  0.06634081 -0.09799434  0.68202427
#    0.20028416  0.39592558]]

# %% [markdown]
# ## Prob

# %%
prob = mdl.predict_proba(x_test)
print(prob)
# Out:
# [[0.71680488 0.28319512]
#  [0.8361073  0.1638927 ]
#  [0.8947119  0.1052881 ]
#  [0.84682701 0.15317299]
#  [0.54147127 0.45852873]
#  [0.55288321 0.44711679]
#  [0.98572545 0.01427455]
#  [0.6226064  0.3773936 ]
#  [0.42644214 0.57355786]
#  [0.24311699 0.75688301]
#  [0.77858311 0.22141689]
#  [0.11121824 0.88878176]
#  [0.60656513 0.39343487]
#  [0.72011056 0.27988944]
#  [0.92374398 0.07625602]
#  [0.59530641 0.40469359]
#  [0.88839551 0.11160449]
#  [0.92578543 0.07421457]
#  [0.2862248  0.7137752 ]
#  [0.42633494 0.57366506]
#  [0.81329522 0.18670478]
#  [0.92363578 0.07636422]
#  [0.48879447 0.51120553]
#  [0.90594349 0.09405651]
#  [0.44072419 0.55927581]
#  [0.11970006 0.88029994]
#  [0.89423226 0.10576774]
#  [0.97083777 0.02916223]
#  [0.737264   0.262736  ]
#  [0.89299983 0.10700017]
#  [0.07591746 0.92408254]
#  [0.14770678 0.85229322]
#  [0.17897964 0.82102036]
#  [0.35074025 0.64925975]
#  [0.43235943 0.56764057]
#  [0.27735925 0.72264075]
#  [0.02683487 0.97316513]
#  [0.79512719 0.20487281]
#  [0.55178555 0.44821445]
#  [0.52124231 0.47875769]
#  [0.93471346 0.06528654]
#  [0.44759568 0.55240432]
#  [0.49285898 0.50714102]
#  [0.69558196 0.30441804]
#  [0.97337812 0.02662188]
#  [0.43296764 0.56703236]
#  [0.34320849 0.65679151]
#  [0.81126951 0.18873049]
#  [0.67120873 0.32879127]
#  [0.03875207 0.96124793]
#  [0.96015494 0.03984506]
#  [0.30513586 0.69486414]
#  [0.15267606 0.84732394]
#  [0.76234055 0.23765945]
#  [0.89265287 0.10734713]
#  [0.96040032 0.03959968]
#  [0.23683671 0.76316329]
#  [0.95329394 0.04670606]
#  [0.58275364 0.41724636]
#  [0.24826929 0.75173071]
#  [0.28243693 0.71756307]
#  [0.69395153 0.30604847]
#  [0.7859629  0.2140371 ]
#  [0.79706994 0.20293006]
#  [0.92187132 0.07812868]
#  [0.38110315 0.61889685]
#  [0.96113486 0.03886514]
#  [0.28145207 0.71854793]
#  [0.96535001 0.03464999]
#  [0.19218088 0.80781912]
#  [0.26481648 0.73518352]
#  [0.94565726 0.05434274]
#  [0.84231155 0.15768845]
#  [0.89004012 0.10995988]
#  [0.91548663 0.08451337]
#  [0.5395633  0.4604367 ]
#  [0.85549599 0.14450401]
#  [0.86234835 0.13765165]
#  [0.85362812 0.14637188]
#  [0.78137081 0.21862919]
#  [0.34877856 0.65122144]
#  [0.84999587 0.15000413]
#  [0.94397641 0.05602359]
#  [0.57704956 0.42295044]
#  [0.74749428 0.25250572]
#  [0.14036105 0.85963895]
#  [0.10673959 0.89326041]
#  [0.67543475 0.32456525]
#  [0.8974507  0.1025493 ]
#  [0.9227568  0.0772432 ]
#  [0.93569754 0.06430246]
#  [0.79094032 0.20905968]
#  [0.96587567 0.03412433]
#  [0.70587086 0.29412914]
#  [0.47314479 0.52685521]
#  [0.37779375 0.62220625]
#  [0.66718223 0.33281777]
#  [0.87934064 0.12065936]
#  [0.30727261 0.69272739]
#  [0.93234253 0.06765747]
#  [0.24871734 0.75128266]
#  [0.9401621  0.0598379 ]
#  [0.23938809 0.76061191]
#  [0.45204474 0.54795526]
#  [0.36301458 0.63698542]
#  [0.75490246 0.24509754]
#  [0.71381639 0.28618361]
#  [0.21961539 0.78038461]
#  [0.8778319  0.1221681 ]
#  [0.52663123 0.47336877]
#  [0.92062124 0.07937876]
#  [0.65942215 0.34057785]
#  [0.84509662 0.15490338]
#  [0.20385311 0.79614689]
#  [0.81221598 0.18778402]
#  [0.70160224 0.29839776]
#  [0.24636281 0.75363719]
#  [0.79997161 0.20002839]
#  [0.94372795 0.05627205]
#  [0.67639863 0.32360137]
#  [0.94610317 0.05389683]
#  [0.69163108 0.30836892]
#  [0.77804666 0.22195334]
#  [0.92911815 0.07088185]
#  [0.73600076 0.26399924]
#  [0.55271204 0.44728796]
#  [0.72152227 0.27847773]
#  [0.11842704 0.88157296]
#  [0.08568352 0.91431648]
#  [0.26772734 0.73227266]
#  [0.2855909  0.7144091 ]
#  [0.12050555 0.87949445]
#  [0.91538019 0.08461981]
#  [0.53724445 0.46275555]
#  [0.14261423 0.85738577]
#  [0.89851105 0.10148895]
#  [0.84672449 0.15327551]
#  [0.14384737 0.85615263]
#  [0.18799122 0.81200878]
#  [0.9884613  0.0115387 ]
#  [0.92085859 0.07914141]
#  [0.96445404 0.03554596]
#  [0.80018961 0.19981039]
#  [0.53466652 0.46533348]
#  [0.89324718 0.10675282]
#  [0.76256226 0.23743774]
#  [0.89144314 0.10855686]
#  [0.9846714  0.0153286 ]
#  [0.61418592 0.38581408]
#  [0.24817123 0.75182877]
#  [0.89168658 0.10831342]
#  [0.56778153 0.43221847]
#  [0.71036861 0.28963139]
#  [0.80776351 0.19223649]]
