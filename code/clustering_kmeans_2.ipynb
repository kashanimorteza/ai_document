# %% [markdown]
# ## Description
# ```
# Number         : 2
# Problem        : Clustering
# Algorithm      : KMeans
# Hyperparameter : Cluster count
# Input          : Feature
# Output         : Cluster
# Dataset        : Unstructured : digits
# ```

# %% [markdown]
# ## Import

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits

# %% [markdown]
# ## Dataset

# %%
digits = load_digits()
x = digits.data
print(x.shape)
# Out:
# (1797, 64)

# %% [markdown]
# ## Display x[0]

# %%
img = x[0]
img = np.reshape(img, (8,8))
print(img.shape)
plt.imshow(img)
# Out:
# (8, 8)
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# ## Train

# %%
mdl = KMeans(n_clusters=10, random_state=0)
mdl.fit(x)
clusters = mdl.predict(x)
cluster_items = mdl.cluster_centers_
print(mdl.cluster_centers_.shape)
# Out:
# (10, 64)

# %% [markdown]
# ## Display clusters

# %%
cluster_items_display = mdl.cluster_centers_.reshape(10, 8, 8)
for i in range(1, 11):
    plt.subplot(2, 5, i)
    plt.imshow(cluster_items_display[i-1])
plt.show()
